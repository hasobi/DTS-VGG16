# %% [markdown]
# <img src = "https://i.imgur.com/UjutVJd.jpg" align = "center">

# %% [markdown]
# # Project Deep Learning
#
# Buatlah model Deep Learning yang mampu mengklasifikasikan 20 kelas gambar dari dataset yang diberikan

# %% [markdown]
# ## Instruksi Pengerjaan
# 1. Copy colab file ke drive masing-masing
# 1. Rename file colab dengan format : `Project_Kelompok.ipynb`
#  * misal kelompok kalian adalah kelompok `1_4`,
#  * maka nama file haruslah `Project_1_4.ipynb`
# 1. Lengkapi bagian kode
# 1. Berikan dokumentasi yang jelas pada setiap cell kode
# ---

# %% [markdown]
# ## Load Modul dan Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

np.set_printoptions(precision=7)
# %matplotlib inline

import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from collections import Counter
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing import image

from PIL import Image

# %% [markdown]
# ---
# # Load Dataset
#
# Proses ini akan mengunduh dataset gambar untuk kasus klasifikasi dengan 20 kelas berdasarkan dataset Pascal VOC 2007

# %% [markdown]
# ## [TASK] Define input size
#
# Rata-rata ukuran gambar adalah `(380, 470, 3)`
#
# Untuk mengurangi komputasi dan memori yang digunakan, resize image menjadi ukuran yang lebih kecil
#
# Tradeoffs:
# * makin kecil gambar, akurasi bisa menurun
# * makin besar gambar, makin berat di komputasi dan memori
#
#
# <br>
#
# <font color='red' size=5><pre>Definisikan ukuran citra yang akan digunakan!</pre></font>

# %%
input_shape = (224, 224, 3)

# %% [markdown]
# ## Load Dataset

# %%
# !wget 'https://raw.githubusercontent.com/adf-telkomuniv/FG_AI_Public/master/others/project_data_loader.py'

from project_data_loader import DataLoader
# Out:
# --2019-08-14 07:57:00--  https://raw.githubusercontent.com/adf-telkomuniv/FG_AI_Public/master/others/project_data_loader.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2567 (2.5K) [text/plain]
# Saving to: ‘project_data_loader.py.5’
#
# project_data_loader 100%[===================>]   2.51K  --.-KB/s    in 0s
#
# 2019-08-14 07:57:00 (81.6 MB/s) - ‘project_data_loader.py.5’ saved [2567/2567]

# %%
loader = DataLoader(input_shape)
(X_train, y_train), (X_val, y_val), (X_test, y_test), class_names = loader.load_data()
# Out:
# W0814 07:57:05.662583 140522179880832 dataset_builder.py:439] Warning: Setting shuffle_files=True because split=TRAIN and shuffle_files=None. This behavior will be deprecated on 2019-08-06, at which point shuffle_files=False will be the default for all splits.

# %%
num_class = len(class_names)

print('terdapat',num_class,'kelas di dalam dataset')
print('daftar kelas:\n', class_names)
# Out:
# terdapat 20 kelas di dalam dataset
# daftar kelas:
#  ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor']

# %% [markdown]
# Cek ukuran dataset

# %%
print('X_train.shape =',X_train.shape)
print('y_train.shape =',y_train.shape)

print('\nX_val.shape   =',X_val.shape)
print('y_val.shape   =',y_val.shape)

print('\nX_test.shape  =',X_test.shape)
print('y_test.shape  =',y_test.shape)
# Out:
# X_train.shape = (2825, 224, 224, 3)
# y_train.shape = (2825,)
#
# X_val.shape   = (2888, 224, 224, 3)
# y_val.shape   = (2888,)
#
# X_test.shape  = (2000, 224, 224, 3)
# y_test.shape  = (2000,)

# %% [markdown]
# **harusnya kalian akan mendapatkan hasil**:
# <pre>X_train.shape = (2825, ??, ??, 3)
# y_train.shape = (2825,)
#
# X_val.shape   = (2888,  ??, ??, 3)
# y_val.shape   = (2888,)
#
# X_test.shape  = (2000, ??, ??, 3)
# y_test.shape  = (2000,)
#
# di mana `??` akan sesuai dengan ukuran `input_shape`
# </pre>

# %%
X_test=X_test[:2000]

X_test
# Out:
# array([[[[119,  97,  50],
#          [119,  98,  51],
#          [116,  98,  52],
#          ...,
#          [149, 127,  63],
#          [148, 124,  62],
#          [146, 122,  60]],
#
#         [[122, 100,  53],
#          [121, 100,  53],
#          [118, 100,  54],
#          ...,
#          [149, 128,  64],
#          [148, 127,  64],
#          [147, 125,  62]],
#
#         [[123, 102,  55],
#          [121, 101,  54],
#          [121, 102,  55],
#          ...,
#          [150, 129,  64],
#          [148, 128,  64],
#          [147, 127,  63]],
#
#         ...,
#
#         [[ 15,  16,  18],
#          [ 17,  20,  21],
#          [ 18,  21,  20],
#          ...,
#          [ 82,  77,  36],
#          [ 89,  80,  39],
#          [ 93,  82,  40]],
#
#         [[ 15,  15,  17],
#          [  9,  11,  12],
#          [ 12,  15,  14],
#          ...,
#          [ 64,  65,  28],
#          [ 66,  66,  29],
#          [ 67,  64,  29]],
#
#         [[ 10,  11,  13],
#          [ 15,  17,  18],
#          [ 17,  20,  19],
#          ...,
#          [ 56,  61,  27],
#          [ 59,  60,  28],
#          [ 60,  59,  27]]],
#
#
#        [[[141, 144, 159],
#          [140, 144, 159],
#          [138, 144, 158],
#          ...,
#          [122, 141, 162],
#          [123, 143, 166],
#          [121, 141, 165]],
#
#         [[139, 142, 159],
#          [138, 143, 157],
#          [139, 145, 159],
#          ...,
#          [124, 143, 164],
#          [123, 141, 165],
#          [122, 140, 164]],
#
#         [[138, 141, 159],
#          [139, 145, 161],
#          [140, 146, 161],
#          ...,
#          [124, 143, 166],
#          [123, 141, 163],
#          [126, 144, 165]],
#
#         ...,
#
#         [[135, 124,  70],
#          [130, 117,  75],
#          [129, 120,  79],
#          ...,
#          [143, 134,  79],
#          [139, 130,  71],
#          [141, 130,  76]],
#
#         [[139, 126,  74],
#          [138, 126,  77],
#          [138, 129,  83],
#          ...,
#          [135, 128,  80],
#          [136, 127,  78],
#          [134, 123,  75]],
#
#         [[142, 128,  83],
#          [133, 121,  74],
#          [142, 132,  86],
#          ...,
#          [126, 120,  75],
#          [135, 125,  83],
#          [136, 123,  80]]],
#
#
#        [[[120, 121, 115],
#          [121, 122, 114],
#          [122, 122, 114],
#          ...,
#          [101, 103,  90],
#          [101, 105,  91],
#          [101, 105,  91]],
#
#         [[122, 123, 117],
#          [121, 121, 115],
#          [123, 123, 115],
#          ...,
#          [101, 103,  90],
#          [100, 104,  90],
#          [101, 105,  91]],
#
#         [[122, 123, 117],
#          [122, 123, 117],
#          [124, 123, 117],
#          ...,
#          [102, 104,  91],
#          [101, 105,  91],
#          [100, 104,  89]],
#
#         ...,
#
#         [[123, 105,  81],
#          [117,  97,  72],
#          [118,  98,  74],
#          ...,
#          [139, 119,  93],
#          [140, 118,  94],
#          [139, 117,  93]],
#
#         [[123, 105,  84],
#          [119,  98,  76],
#          [117,  97,  73],
#          ...,
#          [140, 119,  94],
#          [138, 118,  92],
#          [137, 117,  91]],
#
#         [[123, 105,  86],
#          [122, 103,  82],
#          [116,  97,  75],
#          ...,
#          [139, 118,  93],
#          [138, 118,  91],
#          [138, 118,  91]]],
#
#
#        ...,
#
#
#        [[[134, 137,  92],
#          [131, 133,  89],
#          [128, 129,  85],
#          ...,
#          [100,  99,  78],
#          [ 94,  97,  75],
#          [ 85,  90,  67]],
#
#         [[130, 133,  88],
#          [126, 128,  83],
#          [122, 123,  81],
#          ...,
#          [ 94,  96,  74],
#          [ 90,  94,  71],
#          [ 87,  91,  68]],
#
#         [[126, 129,  86],
#          [119, 122,  79],
#          [114, 116,  76],
#          ...,
#          [ 99, 101,  77],
#          [ 91,  95,  70],
#          [ 86,  91,  65]],
#
#         ...,
#
#         [[133, 149,  82],
#          [138, 154,  93],
#          [140, 154, 102],
#          ...,
#          [212, 219, 212],
#          [214, 224, 200],
#          [167, 179, 142]],
#
#         [[135, 154,  89],
#          [136, 153,  92],
#          [139, 154, 103],
#          ...,
#          [215, 222, 216],
#          [215, 225, 203],
#          [169, 181, 145]],
#
#         [[125, 144,  81],
#          [141, 157, 100],
#          [114, 127,  82],
#          ...,
#          [213, 223, 216],
#          [214, 225, 204],
#          [168, 180, 147]]],
#
#
#        [[[134, 137,  92],
#          [131, 133,  89],
#          [128, 129,  85],
#          ...,
#          [100,  99,  78],
#          [ 94,  97,  75],
#          [ 85,  90,  67]],
#
#         [[130, 133,  88],
#          [126, 128,  83],
#          [122, 123,  81],
#          ...,
#          [ 94,  96,  74],
#          [ 90,  94,  71],
#          [ 87,  91,  68]],
#
#         [[126, 129,  86],
#          [119, 122,  79],
#          [114, 116,  76],
#          ...,
#          [ 99, 101,  77],
#          [ 91,  95,  70],
#          [ 86,  91,  65]],
#
#         ...,
#
#         [[133, 149,  82],
#          [138, 154,  93],
#          [140, 154, 102],
#          ...,
#          [212, 219, 212],
#          [214, 224, 200],
#          [167, 179, 142]],
#
#         [[135, 154,  89],
#          [136, 153,  92],
#          [139, 154, 103],
#          ...,
#          [215, 222, 216],
#          [215, 225, 203],
#          [169, 181, 145]],
#
#         [[125, 144,  81],
#          [141, 157, 100],
#          [114, 127,  82],
#          ...,
#          [213, 223, 216],
#          [214, 225, 204],
#          [168, 180, 147]]],
#
#
#        [[[ 19,  20,  13],
#          [ 20,  21,  15],
#          [ 20,  21,  15],
#          ...,
#          [ 49,  76,  45],
#          [ 53,  78,  49],
#          [ 67,  92,  63]],
#
#         [[ 23,  25,  16],
#          [ 22,  23,  15],
#          [ 26,  27,  19],
#          ...,
#          [ 28,  55,  26],
#          [ 45,  72,  39],
#          [103, 130,  95]],
#
#         [[ 29,  30,  18],
#          [ 31,  31,  20],
#          [ 33,  33,  23],
#          ...,
#          [ 60,  87,  59],
#          [ 55,  81,  50],
#          [ 65,  92,  59]],
#
#         ...,
#
#         [[ 20,  23,  10],
#          [ 62,  63,  43],
#          [ 94,  93,  63],
#          ...,
#          [ 70,  75,  56],
#          [ 84,  89,  66],
#          [110, 113,  89]],
#
#         [[ 63,  63,  41],
#          [108, 107,  78],
#          [ 98,  97,  67],
#          ...,
#          [116, 121,  98],
#          [ 97, 101,  76],
#          [117, 118,  91]],
#
#         [[ 60,  54,  34],
#          [109, 107,  73],
#          [ 80,  79,  50],
#          ...,
#          [131, 136, 110],
#          [133, 137, 109],
#          [132, 132, 104]]]], dtype=uint8)

# %% [markdown]
# ---
# ## [TASK] One-hot Label
#
# <font color='red' size=5><pre>Ubah vektor y_train, y_val, dan y_test menjadi bentuk one hot matrix</pre></font>

# %%
y_train_hot = to_categorical(y_train)
y_val_hot   = to_categorical(y_val)
y_test_hot  = to_categorical(y_test)

print('y_train_hot.shape =',y_train_hot.shape)
print('y_val_hot.shape   =',y_val_hot.shape)
print('y_test_hot.shape  =',y_test_hot.shape)
# Out:
# y_train_hot.shape = (2825, 20)
# y_val_hot.shape   = (2888, 20)
# y_test_hot.shape  = (2000, 20)

# %% [markdown]
# **harusnya kalian akan mendapatkan hasil**:
# <pre>y_train_hot.shape = (2825, 20)
# y_val_hot.shape   = (2888, 20)
# y_test_hot.shape  = (2000, 20)
# </pre>

# %% [markdown]
# ## View Dataset

# %%
fig, ax = plt.subplots(4,10,figsize=(15,8))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
for j in range(0,4):
    for i in range(0, 10):
        ax[j,i].imshow(X_train[i+j*10,:,:,:])
        ax[j,i].set_title(class_names[y_train[i+j*10]])
        ax[j,i].axis('off')
plt.show()

# %% [markdown]
# ---
# # Classification Model

# %% [markdown]
# ## [TASK] Create your own model
# <font color='red' size=5><pre>Buatlah model klasifikasimu sendiri!!</pre></font>
#
#
# Misalnya:
# * load pretrain
# * define new layers
# * define trainable layers
# * have fun

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

np.set_printoptions(precision=7)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras import Model
from tensorflow.keras.layers import Input

from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image

# %%
#Menggunakan VGG16


model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape, pooling='avg')

x = model.output
x = Dense(1024, activation='relu')(x)
predictions = Dense(num_class, activation='softmax')(x)

myModel_imagenet = Model(inputs=model.input, outputs=predictions, name='VGG ImageNet')
myModel_imagenet.summary()
# Out:
# Model: "VGG ImageNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                20500
# =================================================================
# Total params: 15,260,500
# Trainable params: 15,260,500
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## [TASK] Compile Model
# <font color='red' size=5><pre>Compile modelmu dengan loss dan metrik pilihanmu!</pre></font>

# %%
opt = tf.keras.optimizers.Adam(lr=0.0001, decay=1e-6)

# %%
# myModel.compile()

myModel_imagenet.compile(loss='categorical_crossentropy',
                        optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ---
# # Data Preparation

# %% [markdown]
# ## [TASK] Normalize Data
#
# <br>
#
# **OPTIONAL TASK**<br>
# <font color='blue' size=5><pre>Normalisasikan data jika diperlukan!</pre></font>
#
#
# have fun

# %% [markdown]
# ## [TASK] Additional Scheme
#
# <br>
#
# **OPTIONAL TASK**<br>
# <font color='blue' size=5><pre>Tambahkan skema dan implementasi yang ingin kalian lakukan</pre></font>
#
#
# Misalnya:
# * Data Augmentation
# * Custom training function
# * Checkpoint
# * Learning Rate Annealing
# * have fun

# %% [markdown]
# ---
# # Train and Testing

# %% [markdown]
# ## [TASK] Train the Model
# <font color='red' size=5><pre>Latih modelmu! <br>Definisikanlah batch size dan epoch!!<br>Gunakan data validasi</pre></font>

# %%
# batch_size=100
# epochs = 20

# %%
# history = myModel_imagenet.fit(X_train, y_train_hot,
#                     batch_size=batch_size,
#                     epochs=epochs,
#                     validation_data=(X_val, y_val_hot),
#                     shuffle=True)
# Out:
# Train on 2825 samples, validate on 2888 samples
# Epoch 1/20
# 2825/2825 [==============================] - 62s 22ms/sample - loss: 2.7824 - acc: 0.2924 - val_loss: 2.4787 - val_acc: 0.2916
# Epoch 2/20
# 2825/2825 [==============================] - 59s 21ms/sample - loss: 2.1797 - acc: 0.3547 - val_loss: 2.1387 - val_acc: 0.3466
# Epoch 3/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 1.8763 - acc: 0.4202 - val_loss: 1.8706 - val_acc: 0.4411
# Epoch 4/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 1.5945 - acc: 0.4917 - val_loss: 1.8097 - val_acc: 0.4557
# Epoch 5/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 1.4197 - acc: 0.5419 - val_loss: 1.7145 - val_acc: 0.4591
# Epoch 6/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 1.2785 - acc: 0.5812 - val_loss: 1.7406 - val_acc: 0.4848
# Epoch 7/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 1.1322 - acc: 0.6212 - val_loss: 1.5427 - val_acc: 0.5159
# Epoch 8/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.9347 - acc: 0.6832 - val_loss: 1.7068 - val_acc: 0.4754
# Epoch 9/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.8582 - acc: 0.7119 - val_loss: 1.6069 - val_acc: 0.5170
# Epoch 10/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.7026 - acc: 0.7487 - val_loss: 1.7965 - val_acc: 0.5284
# Epoch 11/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.6267 - acc: 0.7752 - val_loss: 1.7600 - val_acc: 0.5336
# Epoch 12/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.5583 - acc: 0.8007 - val_loss: 1.8296 - val_acc: 0.5211
# Epoch 13/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.5447 - acc: 0.8050 - val_loss: 1.7477 - val_acc: 0.5402
# Epoch 14/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.4861 - acc: 0.8255 - val_loss: 1.6714 - val_acc: 0.5312
# Epoch 15/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.4735 - acc: 0.8212 - val_loss: 1.5695 - val_acc: 0.5568
# Epoch 16/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.4586 - acc: 0.8205 - val_loss: 1.5849 - val_acc: 0.5405
# Epoch 17/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.4033 - acc: 0.8407 - val_loss: 1.8581 - val_acc: 0.5419
# Epoch 18/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3966 - acc: 0.8446 - val_loss: 2.0326 - val_acc: 0.4830
# Epoch 19/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.4229 - acc: 0.8386 - val_loss: 1.8173 - val_acc: 0.5589
# Epoch 20/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3817 - acc: 0.8435 - val_loss: 1.5828 - val_acc: 0.5499

# %%
"""
Tambahan
"""
from tensorflow.keras.preprocessing.image import ImageDataGenerator

ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %%
myModel_imagenet.fit(X_train,y_train_hot)
# Out:
# 2825/2825 [==============================] - 53s 19ms/sample - loss: 0.8822 - acc: 0.7044

# %%
opt = tf.keras.optimizers.Adam(lr=0.0001, decay=1e-6)

# %%
batch_size=100
epochs = 20

# %%
myModel_imagenet.compile(loss='categorical_crossentropy',
                        optimizer=opt, metrics=['accuracy'])

# %%
history = myModel_imagenet.fit(X_train, y_train_hot,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(X_val, y_val_hot),
                    shuffle=True)
# Out:
# Train on 2825 samples, validate on 2888 samples
# Epoch 1/20
# 2825/2825 [==============================] - 62s 22ms/sample - loss: 0.5771 - acc: 0.7904 - val_loss: 1.6378 - val_acc: 0.5519
# Epoch 2/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3873 - acc: 0.8365 - val_loss: 1.5934 - val_acc: 0.5575
# Epoch 3/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3547 - acc: 0.8499 - val_loss: 1.6572 - val_acc: 0.5620
# Epoch 4/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3584 - acc: 0.8485 - val_loss: 1.6651 - val_acc: 0.5398
# Epoch 5/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3428 - acc: 0.8499 - val_loss: 1.6254 - val_acc: 0.5727
# Epoch 6/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3267 - acc: 0.8566 - val_loss: 1.6647 - val_acc: 0.5547
# Epoch 7/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3207 - acc: 0.8609 - val_loss: 1.7769 - val_acc: 0.5436
# Epoch 8/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3146 - acc: 0.8570 - val_loss: 1.8773 - val_acc: 0.5194
# Epoch 9/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3394 - acc: 0.8510 - val_loss: 1.5813 - val_acc: 0.5689
# Epoch 10/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3057 - acc: 0.8510 - val_loss: 1.6991 - val_acc: 0.5641
# Epoch 11/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.3048 - acc: 0.8549 - val_loss: 1.6263 - val_acc: 0.5613
# Epoch 12/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2863 - acc: 0.8538 - val_loss: 1.5707 - val_acc: 0.5703
# Epoch 13/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2841 - acc: 0.8538 - val_loss: 1.8107 - val_acc: 0.5544
# Epoch 14/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2933 - acc: 0.8492 - val_loss: 1.7027 - val_acc: 0.5533
# Epoch 15/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2766 - acc: 0.8531 - val_loss: 1.7370 - val_acc: 0.5571
# Epoch 16/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2799 - acc: 0.8538 - val_loss: 1.6550 - val_acc: 0.5686
# Epoch 17/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2674 - acc: 0.8510 - val_loss: 1.6541 - val_acc: 0.5661
# Epoch 18/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2593 - acc: 0.8450 - val_loss: 1.6978 - val_acc: 0.5689
# Epoch 19/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2603 - acc: 0.8538 - val_loss: 1.6192 - val_acc: 0.5755
# Epoch 20/20
# 2825/2825 [==============================] - 60s 21ms/sample - loss: 0.2503 - acc: 0.8531 - val_loss: 1.8560 - val_acc: 0.5751

# %% [markdown]
# ## Plot History Training

# %%
# plt.rcParams['figure.figsize'] = [7, 5]

# plt.plot(history.history['acc'], label='train')
# plt.plot(history.history['val_acc'], label='val')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %%
plt.rcParams['figure.figsize'] = [7, 5]

plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='val')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## [TASK] Evaluasi Model
# <font color='red' size=5><pre>Evaluasikan modelmu pada data test</pre></font>

# %%
scores = myModel_imagenet.evaluate(X_test, y_test_hot, verbose=1)
# Out:
# 2000/2000 [==============================] - 11s 6ms/sample - loss: 1.9649 - acc: 0.5605

# %%
print('Test loss    :', scores[0])
print('Test accuracy: %.2f%%' % (scores[1]*100))
# Out:
# Test loss    : 1.9649266023635865
# Test accuracy: 56.05%

# %% [markdown]
# ---
# # Save Model

# %% [markdown]
# ## [TASK] Save model into .h5 file
#
# <font color='red' size=5><pre>Simpan model terbaikmu dengan nama file 'model_kelompok.h5'</pre></font>
#
# * misal kelompok kalian adalah kelompok `3_2`,
# * maka nama file model haruslah `model_3_2.h5`

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
myModel_imagenet.save('model_3_6.h5')

# %% [markdown]
# ## [TASK] Download model
#
#
# <font color='red' size=5><pre>Download modelmu dari tab `Files`</pre></font>

# %% [markdown]
# ## [TASK] Upload model
#
#
# <font color='red' size=5><pre>Upload modelmu ke suatu storage cloud,<br>Kumpulkan link di google sheet daftar kelompok</pre></font>

# %% [markdown]
# ## [TASK] Share File Colab
#
#
# <font color='red' size=5><pre>Share dan Set file colaboratory ini agar bisa dilihat oleh orang lain<br>
# Copy link file colaboratory
# Lalu kumpulkan link di google sheet daftar kelompok</pre></font>

# %% [markdown]
# ---
# # Menguji Pada Image Dari Internet
#
# <br>
#
# **OPTIONAL TASK**<br>
# <font color='blue' size=5><pre>tambahkan 5 gambar baru, dan coba modelmu terhadap gambar tersebut</pre></font>
#
# * Search Gambar di Internet (Google Image)
# * Copy Image Address
# * Paste Image Address ke cell di bawah

# %%
# !wget -O 'data_test_0.jpg' '??'
# !wget -O 'data_test_1.jpg' '??'
# !wget -O 'data_test_2.jpg' '??'
# !wget -O 'data_test_3.jpg' '??'
# !wget -O 'data_test_4.jpg' '??'

# %%
for i in range(5):
  new_img = Image.open('data_test_'+str(i)+'.jpg')
  new_img = np.array(new_img)
  new_img2 = cv.resize(new_img, input_shape[:2], interpolation=cv.INTER_AREA)
  plt.imshow(new_img2)
  plt.axis('off')
  plt.show()

  new_img2 = np.expand_dims(new_img2,0)
  pred = myModel.predict(new_img2)
  class_id = np.argmax(pred)
  print('id kelas prediksi',class_id)
  print('kelas prediksi', class_names[class_id])

# %% [markdown]
# <p>Copyright &copy; 2019 <a href=https://www.linkedin.com/in/andityaarifianto/>ADF</a> </p>
